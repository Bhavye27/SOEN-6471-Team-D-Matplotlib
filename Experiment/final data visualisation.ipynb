# %% [markdown]
# ## Project on FIFA Data Analysis and Visualization

# %% [markdown]
# ### INTRODUCTION
#
# 1. Import required libraries
# 2. Loading the dataset
# 3. Feature Selection
# 3. Check the missing values with visualization
# 4. Data Cleaning
# 5. Data Visualization
#
#         --Bar chart :Most prefferd foot of the player in the FIFA 2019
#         --Line chart:Potential and overall in the FIFA 2019
#         --Bar Chart :Potential of  participants in the FIFA 2019
#         --Bar Chart :Different nations participating in the FIFA 2019
#         --Histogram :Different overall scores of the players participating in the FIFA 2019
#         --Histogram :Different age of player in the FIFA 2019
#         --ScatterPlot:ShotPower and Finishing in the FIFA 2019
#         --Horizontal Bar chart : Total player of different nations in the FIFA 2019
#         --Heatmap
# 6. Data Analysis

# %% [markdown]
# ###  1. Import required libraries:

# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-128-763f68a9b1e9> in <module>
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
# ----> 6 from wordcloud import WordCloud
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# ### 2. Loading the dataset:

# %%
#import data
data = pd.read_csv('C:/Users/Raviii/Desktop/data.csv')
data.head()

# %% [markdown]
# ### 3. Feature Selection

# %%
##Returns the sorted unique elements of an array(Nationality). 

data.Nationality.unique()

# %%
# view dataframe summary

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
# describe statastical information such as count, mean ,min,max

data.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
##Returns the sorted unique elements of an array(Club). 

data.Club.unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Paris Saint-Germain',
#        'Manchester United', 'Manchester City', 'Chelsea', 'Real Madrid',
#        'Atlético Madrid', 'FC Bayern München', 'Tottenham Hotspur',
#        'Liverpool', 'Napoli', 'Arsenal', 'Milan', 'Inter', 'Lazio',
#        'Borussia Dortmund', 'Vissel Kobe', 'Olympique Lyonnais', 'Roma',
#        'Valencia CF', 'Guangzhou Evergrande Taobao FC', 'FC Porto',
#        'FC Schalke 04', 'Beşiktaş JK', 'LA Galaxy', 'Sporting CP',
#        'Real Betis', 'Olympique de Marseille', 'RC Celta',
#        'Bayer 04 Leverkusen', 'Real Sociedad', 'Villarreal CF',
#        'Sevilla FC', 'SL Benfica', 'AS Saint-Étienne', 'AS Monaco',
#        'Leicester City', 'Atalanta', 'Grêmio', 'Atlético Mineiro',
#        'RB Leipzig', 'Ajax', 'Dalian YiFang FC', 'Everton',
#        'West Ham United', '1. FC Köln', 'TSG 1899 Hoffenheim',
#        'Shanghai SIPG FC', 'OGC Nice', 'Al Nassr',
#        'Wolverhampton Wanderers', 'Borussia Mönchengladbach',
# ...

# %%
# lets count total player of different nation
data.Nationality.value_counts()
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
#              ...
# Jordan          1
# Guam            1
# Lebanon         1
# Belize          1
# Palestine       1
# Name: Nationality, Length: 164, dtype: int64

# %% [markdown]
# ### 4. Data Cleaning:

# %%
# lets check if there is null data or not.

data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
# Lets fill that data with appropriate value
# fillna is pandas function used for replace missing valaue with some value.

data['ShortPassing'].fillna(data['ShortPassing'].mean(), inplace = True)
data['Volleys'].fillna(data['Volleys'].mean(), inplace = True)
data['Dribbling'].fillna(data['Dribbling'].mean(), inplace = True)
data['Curve'].fillna(data['Curve'].mean(), inplace = True)
data['FKAccuracy'].fillna(data['FKAccuracy'], inplace = True)
data['LongPassing'].fillna(data['LongPassing'].mean(), inplace = True)
data['BallControl'].fillna(data['BallControl'].mean(), inplace = True)
data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace = True)
data['Finishing'].fillna(data['Finishing'].mean(), inplace = True)
data['Crossing'].fillna(data['Crossing'].mean(), inplace = True)
data['Weight'].fillna('200lbs', inplace = True)
data['Contract Valid Until'].fillna(2019, inplace = True)
data['Height'].fillna("5'11", inplace = True)
data['Loaned From'].fillna('None', inplace = True)
data['Joined'].fillna('Jul 1, 2018', inplace = True)
data['Jersey Number'].fillna(8, inplace = True)
data['Body Type'].fillna('Normal', inplace = True)
data['Position'].fillna('ST', inplace = True)
data['Club'].fillna('No Club', inplace = True)
data['Work Rate'].fillna('Medium/ Medium', inplace = True)
data['Skill Moves'].fillna(data['Skill Moves'].median(), inplace = True)
data['Weak Foot'].fillna(3, inplace = True)
data['Preferred Foot'].fillna('Right', inplace = True)
data['International Reputation'].fillna(1, inplace = True)
data['Wage'].fillna('€200K', inplace = True)

# %% [markdown]
# ### 5. Data Visualisation:

# %%
#lets see most prefferd foot of the player

graph=sns.countplot(data['Preferred Foot'], palette = 'pink')
plt.title('Most Preferred Foot of the Players', fontsize = 20)

for p in graph.patches:
    height = p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1,height ,ha="center")

plt.show()

# %%
#lets see Line plot of Potential and overall

data.Potential.plot(kind = 'line',color ='c', label = 'Potential', linewidth = 1, alpha = 0.5, grid = True)
data.Overall.plot(color = 'r', label = 'Overall', linewidth= 1, alpha = 0.5, grid = True)
plt.legend(loc = 'upper right')   
plt.xlabel('x axis')              
plt.ylabel('y axis')
plt.title('Line plot')          
plt.show()

# %%
# lets see potential of  participants in the FIFA 2019

plt.figure(figsize = (15, 7))
plt.style.use('_classic_test')

sns.countplot(x = 'Potential', data = data, palette = 'hls')
plt.title('Different Potential of the Players Participating in the FIFA 2019', fontsize = 20)
plt.xlabel('Potential rates associated with the players', fontsize = 16)
plt.ylabel('count of Players', fontsize = 16)
plt.show()

# %%
# lets see different nations participating in the FIFA 2019

plt.style.use('dark_background')
data['Nationality'].value_counts().head(50).plot.bar(color = 'blue', figsize = (20, 7))
plt.title('Different Nations Player Participating in FIFA 2019', fontsize = 30, fontweight = 20)
plt.xlabel('Name of The Country')
plt.ylabel('count')
plt.show()

# %%
# lets see different overall scores of the players participating in the FIFA 2019

x = data.Overall
plt.figure(figsize = (12,8))
plt.style.use('ggplot')
plt.hist(x,bins=52,color='c')
plt.xlabel(xlabel = "Player\'s Scores", fontsize = 16)
plt.ylabel(ylabel = 'Number of players', fontsize = 16)
plt.title(label = 'Histogram of players Overall Scores', fontsize = 20)
plt.show()

# %%
# lets see age of player 
plt.figure(figsize = (12,8))
plt.hist(data.Age, bins =58  , color= 'y')
plt.xlabel("Player age",fontsize=16)
plt.ylabel("Number of Players",fontsize=16)
plt.title("Players ages graph",fontsize = 20)
plt.show()

# %%
# lets see Scatter Plot of shotPower and Finishing
plt.figure(figsize = (12,8))
data.plot(kind = 'scatter', x='Finishing', y ='ShotPower', color = 'red')
plt.xlabel('Finishing')    
plt.ylabel('ShotPower')
plt.title('Finishing ShotPower Scatter Plot')
plt.show()

# %%
# lets see total player of different nations

top_country = data['Nationality'].value_counts().head(15)
fig,ax = plt.subplots(figsize=(12,8))
x = top_country.values
y = top_country.index
ax.barh(y, x, align='center', color='dimgray')
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Number of Players')
ax.set_ylabel('Name of Countries')
ax.set_title('Top 10 Countries with most number of players')
plt.show()

# %%
# Lets see What are the main attributes of the top 18 players?

heatmap_data = data.loc[:,['Name','Overall','Crossing',
       'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
       'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes']].sort_values("Overall",ascending=False).set_index("Name").head(18)

plt.title("Top 20 players attribute map")
sns.heatmap(heatmap_data, annot=True, cmap="Greens")

# %% [markdown]
# ### 6. Data Analysis

# %%
# Top 10 players by position for reference

positions = ['CAM', 'CB', 'CDM', 'CF', 'CM', 'LAM',
       'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF',
       'RM', 'RS', 'RW', 'RWB']

for i in positions:
    print('\n\n','Top 10', i, 'in FIFA 19', '\n')
    print(data.sort_values(i, ascending=False).head(10).reset_index()[['Name', 'Nationality', 'Club', 'Overall']])
# Out:
#  Top 10 CAM in FIFA 19
#
#                 Name Nationality                 Club  Overall
# 0           L. Messi   Argentina         FC Barcelona       94
# 1          Neymar Jr      Brazil  Paris Saint-Germain       92
# 2          E. Hazard     Belgium              Chelsea       91
# 3  Cristiano Ronaldo    Portugal             Juventus       94
# 4       K. De Bruyne     Belgium      Manchester City       91
# 5          P. Dybala   Argentina             Juventus       89
# 6        David Silva       Spain      Manchester City       90
# 7           Coutinho      Brazil         FC Barcelona       88
# 8          L. Modrić     Croatia          Real Madrid       91
# 9          K. Mbappé      France  Paris Saint-Germain       88
#
#
#  Top 10 CB in FIFA 19
#
#             Name  Nationality                 Club  Overall
# 0   Sergio Ramos        Spain          Real Madrid       91
# 1       D. Godín      Uruguay      Atlético Madrid       90
# ...

# %%
def country(x):
    return data[data['Nationality'] == x][['Name','Overall','Potential','Position']]

# let's check the Indian Players 
country('India')
# Out:
#                   Name  Overall  Potential Position
# 8605        S. Chhetri       67         67       LS
# 10011       S. Jhingan       65         71      RCB
# 12598    J. Lalpekhlua       63         64       RS
# 12811  G. Singh Sandhu       63         68       GK
# 13508    A. Edathodika       62         62      LCB
# 14054        P. Halder       61         67      RCM
# 14199         P. Kotal       61         66       RB
# 14218         L. Ralte       61         62       LW
# 14705           N. Das       60         65       LB
# 14786         U. Singh       60         67       RM
# 14915       H. Narzary       60         66       LM
# 15356         R. Singh       59         59       ST
# 15643         S. Singh       59         65       CB
# 15652         A. Thapa       59         71      LCM
# 15855       M. Rafique       58         61       CM
# 15864         A. Singh       58         62       GK
# 15884         B. Singh       58         58       ST
# ...

# %%
# Filter data using club name

def club(x):
    return data[data['Club'] == x ][['Name','Jersey Number','Position','Overall','Nationality','Age','Wage','Value','Contract Valid Until' ]]
                                     
club('Manchester United')
# Out:
#                   Name  Jersey Number Position  Overall  Nationality  Age  \
# 3               De Gea            1.0       GK       91        Spain   27
# 45            P. Pogba            6.0      RDM       87       France   25
# 47           R. Lukaku            9.0       ST       87      Belgium   25
# 93          A. Sánchez            7.0       RW       85        Chile   29
# 116         A. Martial           11.0       LW       84       France   22
# 132           N. Matić           31.0      CDM       84       Serbia   29
# 211          Juan Mata            8.0       RM       83        Spain   30
# 250               Fred           17.0       CM       82       Brazil   25
# 254         J. Lingard            7.0      CAM       82      England   25
# 319        M. Rashford           11.0       LW       81      England   20
# 327          E. Bailly            2.0       CB       81  Ivory Coast   24
# 374      Ander Herrera           21.0       CM       81        Spain   28
# ...

# %%
# The five eldest players

eldest = data.sort_values('Age', ascending = False)[['Name', 'Nationality', 'Age']].head(5)
eldest.set_index('Name', inplace=True)
print(eldest)
# Out:
#                      Nationality  Age
# Name
# O. Pérez                  Mexico   45
# K. Pilkington            England   44
# T. Warner      Trinidad & Tobago   44
# S. Narazaki                Japan   42
# C. Muñoz               Argentina   41

# %%
# The ten youngest players
eldest = data.sort_values('Age', ascending = True)[['Name', 'Nationality', 'Age']].head(10)
eldest.set_index('Name', inplace=True)
print(eldest)
# Out:
#                         Nationality  Age
# Name
# G. Nugent                   England   16
# J. Olstad                    Norway   16
# H. Massengo                  France   16
# J. Italiano               Australia   16
# N. Ayéva                     Sweden   16
# K. Broda                     Poland   16
# L. D'Arrigo               Australia   16
# Y. Verschaeren              Belgium   16
# B. Nygren                    Sweden   16
# B. O'Gorman     Republic of Ireland   16

# %%
# Top five teams with the best players
data.groupby(['Club'])['Overall'].max().sort_values(ascending = False).head()
# Out:
# Club
# Juventus               94
# FC Barcelona           94
# Paris Saint-Germain    92
# Real Madrid            91
# Chelsea                91
# Name: Overall, dtype: int64

# %%
# Top 5 left-footed players
data[data['Preferred Foot'] == 'Left'][['Name','Overall']].head()
# Out:
#             Name  Overall
# 0       L. Messi       94
# 13   David Silva       90
# 15     P. Dybala       89
# 17  A. Griezmann       89
# 19   T. Courtois       89

# %%
#lets make a function that choose the best player to different position in the data 

# goalkeeping positions
goal_pos = ["GK"]

# defensive positions
def_pos = ["CB", "LB", "RB", "LWB", "RWB", "RCB", "LCB"]

# midfield positions
mid_pos = ["CDM", "RDM", "LDM", "CAM", "LAM", "RAM", "CM", "LM", "RM", "RW", "LW", "RCM", "LCM"]

# attacking positions
att_pos = ["CF", "ST", "LF", "RF", "LS", "RS"]

#Graph the top players by position.

def graph_top_by_position(position, column1, column2, num_of_players):
    
    # create a dictionary to retrive the corresponding value from position argument
    lists = {"goalkeepers":goal_pos, "defenders":def_pos, "midfielders":mid_pos, "attackers":att_pos}
    # DataFrame of top players
    top_players = data[data["Position"].isin(lists.get(position))].head(num_of_players)
    # DataFrame columns converted to lists
    names = top_players["Name"].to_list()
    rating = top_players[column1].to_list()
    value = top_players[column2].to_list()
    names.reverse()
    rating.reverse()
    value.reverse()
    # Plotting
    fig, axs = plt.subplots(2)
    fig.suptitle("Top "+str(num_of_players)+" "+position)
    axs[0].set_ylabel("Player name")
    axs[0].set_xlabel("Overall rating")
    axs[1].set_ylabel("Player name")
    axs[1].set_xlabel("Market value (by hundreds of millions)")
    ax1 = axs[0].barh(names, width=rating)
    ax2 = axs[1].barh(names, width=value)
    colors = ['#80ffaa', '#4dff88', '#1aff66', '#00cc44', '#009933']
    x=0
    for x in range(5):
        ax1[x].set_color(colors[x])
        ax2[x].set_color(colors[x])
    plt.show()

# %%
# lets plot top 5 goal keeper by overall rating and their market value

graph_top_by_position('goalkeepers','Overall','Value',5)
